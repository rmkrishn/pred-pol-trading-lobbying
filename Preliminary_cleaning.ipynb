# %% [markdown]
# ## Some data cleaning

# %% [markdown]
# We now tidy up some of the data we are working with. Here are a few of the initial goals:
# 1. Identify which lobbying reports are relevant, and which we should remove from our consideration.
# 2. Remove a bunch of unimportant columns from the lobbying data.
# 3. Explicate and standardize the lobbying issue codes (sectors for lobbying activity).
# 4. Classify stocks bought by industry, i.e. match each stock to one or more sectors from 3.

# %% [markdown]
# We import the necessary packages here.

# %%
import numpy as np
import pandas as pd
import ast
# Out:
# /var/folders/ln/nt00cb4n18752q_3n96dk_2c0000gn/T/ipykernel_73847/1730776239.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ### Which filing codes are important?

# %% [markdown]
# Let's look at a few codes. Recall that they are of the following form (omitting M and Y codes since there were no filings labelled as such).

# %%
filing_types=["RR","RA","Q1","Q1Y","1T","1TY","1A","1AY","1@","1@Y","Q2","Q2Y","2T","2TY","2A","2AY","2@","2@Y","Q3","Q3Y","3T","3TY","3A","3AY","3@","3@Y","Q4","Q4Y","4T","4TY","4A","4AY","4@","4@Y"]

# %% [markdown]
# In the end, registrations (RR and RA) will not relevant to us, since there is no report of income or expenses on the registration form (this form is called form "LD-1" by the office of the Senate). See, for example, https://lda.senate.gov/filings/public/filing/286588cd-7cfd-4a82-a4a0-c5bd9265f868/print/.

# %% [markdown]
# While it is tempting to ignore codes involving Y, since Y is supposed to represent no activity, it seems very possible that firms can report income or expenses when filing a Y code.

# %%
lobbying_2023_Q1Y=pd.read_csv("../../lobbying-local-data/LDA_data/Filings_2023/filings_2023_Q1Y.csv")

# %%
lobbying_2023_Q1Y["expenses"]=lobbying_2023_Q1Y["expenses"].fillna(0)
lobbying_2023_Q1Y["income"]=lobbying_2023_Q1Y["income"].fillna(0)

# %%
lobbying_2023_Q1Y.loc[(lobbying_2023_Q1Y["expenses"]!=0) | (lobbying_2023_Q1Y["income"]!=0)]
# Out:
#                                                     url  \
# 4     https://lda.senate.gov/api/v1/filings/2f3f7ad4...
# 27    https://lda.senate.gov/api/v1/filings/d18f7814...
# 28    https://lda.senate.gov/api/v1/filings/0afef369...
# 32    https://lda.senate.gov/api/v1/filings/22cb9607...
# 38    https://lda.senate.gov/api/v1/filings/3e0840b3...
# ...                                                 ...
# 2416  https://lda.senate.gov/api/v1/filings/a8d42fc9...
# 2417  https://lda.senate.gov/api/v1/filings/b10e92f1...
# 2427  https://lda.senate.gov/api/v1/filings/9678095e...
# 2433  https://lda.senate.gov/api/v1/filings/9e0a0976...
# 2435  https://lda.senate.gov/api/v1/filings/7d57a313...
#
#                                filing_uuid filing_type  \
# 4     2f3f7ad4-aa65-4272-9748-cd6b2d486375         Q1Y
# 27    d18f7814-89bb-43d2-b069-2ec862e55fed         Q1Y
# 28    0afef369-ebe1-442e-9f82-2b123da38939         Q1Y
# 32    22cb9607-85d5-48a0-a834-a593e69441f8         Q1Y
# 38    3e0840b3-b361-43fb-8a18-31494f879e76         Q1Y
# ...                                    ...         ...
# 2416  a8d42fc9-621b-4cf0-81fa-d2248f727d8f         Q1Y
# 2417  b10e92f1-f075-455c-aceb-f826d020b561         Q1Y
# 2427  9678095e-ad4b-4c7e-a068-500641560c29         Q1Y
# 2433  9e0a0976-a2f1-4f66-9206-499d593a1c96         Q1Y
# 2435  7d57a313-0b80-44bb-837f-7a84b979a088         Q1Y
#
#                      filing_type_display  filing_year  filing_period  \
# 4     1st Quarter - Report (No Activity)         2023  first_quarter
# 27    1st Quarter - Report (No Activity)         2023  first_quarter
# 28    1st Quarter - Report (No Activity)         2023  first_quarter
# 32    1st Quarter - Report (No Activity)         2023  first_quarter
# 38    1st Quarter - Report (No Activity)         2023  first_quarter
# ...                                  ...          ...            ...
# 2416  1st Quarter - Report (No Activity)         2023  first_quarter
# 2417  1st Quarter - Report (No Activity)         2023  first_quarter
# 2427  1st Quarter - Report (No Activity)         2023  first_quarter
# 2433  1st Quarter - Report (No Activity)         2023  first_quarter
# 2435  1st Quarter - Report (No Activity)         2023  first_quarter
#
#              filing_period_display  \
# 4     1st Quarter (Jan 1 - Mar 31)
# 27    1st Quarter (Jan 1 - Mar 31)
# 28    1st Quarter (Jan 1 - Mar 31)
# 32    1st Quarter (Jan 1 - Mar 31)
# 38    1st Quarter (Jan 1 - Mar 31)
# ...                            ...
# 2416  1st Quarter (Jan 1 - Mar 31)
# 2417  1st Quarter (Jan 1 - Mar 31)
# 2427  1st Quarter (Jan 1 - Mar 31)
# 2433  1st Quarter (Jan 1 - Mar 31)
# 2435  1st Quarter (Jan 1 - Mar 31)
#
#                                     filing_document_url  \
# 4     https://lda.senate.gov/filings/public/filing/2...
# 27    https://lda.senate.gov/filings/public/filing/d...
# 28    https://lda.senate.gov/filings/public/filing/0...
# 32    https://lda.senate.gov/filings/public/filing/2...
# 38    https://lda.senate.gov/filings/public/filing/3...
# ...                                                 ...
# 2416  https://lda.senate.gov/filings/public/filing/a...
# 2417  https://lda.senate.gov/filings/public/filing/b...
# 2427  https://lda.senate.gov/filings/public/filing/9...
# 2433  https://lda.senate.gov/filings/public/filing/9...
# 2435  https://lda.senate.gov/filings/public/filing/7...
#
#      filing_document_content_type   income  ...  registrant_different_address  \
# 4                       text/html  10000.0  ...                         False
# 27                      text/html      0.0  ...                          True
# 28                      text/html  15000.0  ...                         False
# 32                      text/html  30000.0  ...                         False
# 38                      text/html  30000.0  ...                          True
# ...                           ...      ...  ...                           ...
# 2416                    text/html  12000.0  ...                         False
# 2417                    text/html  20000.0  ...                         False
# 2427                    text/html  40000.0  ...                         False
# 2433                    text/html  40000.0  ...                         False
# 2435                    text/html      0.0  ...                         False
#
#      registrant_city registrant_state registrant_zip  \
# 4         Washington               DC        20001.0
# 27        Sperryvile               VA        22740.0
# 28       Centreville               VA        20122.0
# 32            Dayton               OH        45440.0
# 38        Washington               DC        20037.0
# ...              ...              ...            ...
# 2416        Valencia               CA        91355.0
# 2417      Washington               DC        20005.0
# 2427      Washington               DC        20002.0
# 2433      Washington               DC        20020.0
# 2435      WASHINGTON               DC        20002.0
#
#                                              registrant  \
# 4     {'id': 401106013, 'url': 'https://lda.senate.g...
# 27    {'id': 401103509, 'url': 'https://lda.senate.g...
# 28    {'id': 286872, 'url': 'https://lda.senate.gov/...
# 32    {'id': 401103216, 'url': 'https://lda.senate.g...
# 38    {'id': 401036920, 'url': 'https://lda.senate.g...
# ...                                                 ...
# 2416  {'id': 401103948, 'url': 'https://lda.senate.g...
# 2417  {'id': 283696, 'url': 'https://lda.senate.gov/...
# 2427  {'id': 30837, 'url': 'https://lda.senate.gov/a...
# 2433  {'id': 401105126, 'url': 'https://lda.senate.g...
# 2435  {'id': 45766, 'url': 'https://lda.senate.gov/a...
#
#                                                  client lobbying_activities  \
# 4     {'id': 54273, 'url': 'https://lda.senate.gov/a...                  []
# 27    {'id': 199224, 'url': 'https://lda.senate.gov/...                  []
# 28    {'id': 176548, 'url': 'https://lda.senate.gov/...                  []
# 32    {'id': 205208, 'url': 'https://lda.senate.gov/...                  []
# 38    {'id': 208525, 'url': 'https://lda.senate.gov/...                  []
# ...                                                 ...                 ...
# 2416  {'id': 200458, 'url': 'https://lda.senate.gov/...                  []
# 2417  {'id': 56600, 'url': 'https://lda.senate.gov/a...                  []
# 2427  {'id': 136234, 'url': 'https://lda.senate.gov/...                  []
# 2433  {'id': 211572, 'url': 'https://lda.senate.gov/...                  []
# 2435  {'id': 153749, 'url': 'https://lda.senate.gov/...                  []
#
#      conviction_disclosures foreign_entities affiliated_organizations
# 4                        []               []                       []
# 27                       []               []                       []
# 28                       []               []                       []
# 32                       []               []                       []
# 38                       []               []                       []
# ...                     ...              ...                      ...
# 2416                     []               []                       []
# 2417                     []               []                       []
# 2427                     []               []                       []
# 2433                     []               []                       []
# 2435                     []               []                       []
#
# [429 rows x 30 columns]

# %% [markdown]
# If a filing is an amendment to a previous filing (i.e. the code involves an "A" or "@"), the information within should be incorporated into the previous filing, so that we don't double count this single datapoint.

# %%
lobbying_2023_RR=pd.read_csv("../../lobbying-local-data/LDA_data/Filings_2023/filings_2023_RR.csv")
lobbying_2023_RA=pd.read_csv("../../lobbying-local-data/LDA_data/Filings_2023/filings_2023_RA.csv")

# %% [markdown]
# Just to see what the columns are, and what a typical entry may look like, here's the 57th row of one of these dataframes.

# %%
lobbying_2023_RR.iloc[57]
# Out:
# url                             https://lda.senate.gov/api/v1/filings/07a08705...
# filing_uuid                                  07a08705-6f68-4bac-afe0-005ae5def8cf
# filing_type                                                                    RR
# filing_type_display                                                  Registration
# filing_year                                                                  2023
# filing_period                                                       first_quarter
# filing_period_display                                1st Quarter (Jan 1 - Mar 31)
# filing_document_url             https://lda.senate.gov/filings/public/filing/0...
# filing_document_content_type                                            text/html
# income                                                                        NaN
# expenses                                                                      NaN
# expenses_method                                                               NaN
# expenses_method_display                                                       NaN
# posted_by_name                                                      Michael Brody
# dt_posted                                               2023-01-16T17:22:35-05:00
# termination_date                                                              NaN
# registrant_country                                       United States of America
# registrant_ppb_country                                                        NaN
# registrant_address_1                                   3299 K street NW Suite 401
# registrant_address_2                                                          NaN
# registrant_different_address                                                  NaN
# registrant_city                                                        Washington
# registrant_state                                                               DC
# registrant_zip                                                            20007.0
# registrant                      {'id': 323318, 'url': 'https://lda.senate.gov/...
# client                          {'id': 53935, 'url': 'https://lda.senate.gov/a...
# lobbying_activities             [{'general_issue_code': 'DEF', 'general_issue_...
# conviction_disclosures                                                         []
# foreign_entities                                                               []
# affiliated_organizations                                                       []
# Name: 57, dtype: object

# %% [markdown]
# A lot of these columns seem to be unimportant. At a first glance, I don't think we will ever use: ["url", "filing_type_display", "filing_period_display", "filing_document_url", "filing_document_content_type", "filing_document_type", "expenses_method_display", "posted_by_name", "dt_posted", "registrant_country", "registrant_ppb_country", "registrant_address_1", "registrant_address_2", "registrant_different_address", "registrant_city", "registrant_state", "registrant_zip"]. Keeping the uuid is nice in case we need to refer to this specific filing for any reason. We will drop these columns later.

# %% [markdown]
# For now, let's match up the amended filings with their corresponding originals. We use ast.literal_eval to access information from those entries which contain strings representing dictionaries. (See discussion on "Dealing with dictionaries...".) We make new columns of our dataframes with the registrant id (senate id) and client id. The amendments will have these exact ids. This lets us match one to the other.

# %%
registrant_ids=[ast.literal_eval(lobbying_2023_RR.iloc[i]["registrant"])["id"] for i in range(len(lobbying_2023_RR))]
client_ids=[ast.literal_eval(lobbying_2023_RR.iloc[i]["client"])["id"] for i in range(len(lobbying_2023_RR))]
lobbying_2023_RR["registrant_id"]=registrant_ids
lobbying_2023_RR["client_id"]=client_ids

# %%
registrant_ids=[ast.literal_eval(lobbying_2023_RA.iloc[i]["registrant"])["id"] for i in range(len(lobbying_2023_RA))]
client_ids=[ast.literal_eval(lobbying_2023_RA.iloc[i]["client"])["id"] for i in range(len(lobbying_2023_RA))]
lobbying_2023_RA["registrant_id"]=registrant_ids
lobbying_2023_RA["client_id"]=client_ids

# %%
lobbying_2023_RR_toamend=pd.DataFrame()
for i in range(len(lobbying_2023_RA)):
    reg_client=[lobbying_2023_RA.iloc[i]["registrant_id"], lobbying_2023_RA.iloc[i]["client_id"]]
    df=lobbying_2023_RR.loc[(lobbying_2023_RR["registrant_id"]==reg_client[0]) & (lobbying_2023_RR["client_id"]==reg_client[1])]
    lobbying_2023_RR_toamend=pd.concat([lobbying_2023_RR_toamend,df])

# %% [markdown]
# Let's sort this by registrant_id, followed by client_id.

# %%
lobbying_2023_RR_toamend.sort_values(["registrant_id","client_id"])
# Out:
#                                                     url  \
# 204   https://lda.senate.gov/api/v1/filings/3199e1d1...
# 3880  https://lda.senate.gov/api/v1/filings/202792f1...
# 2653  https://lda.senate.gov/api/v1/filings/52508a4d...
# 3566  https://lda.senate.gov/api/v1/filings/0e461030...
# 2372  https://lda.senate.gov/api/v1/filings/650b9e5a...
# ...                                                 ...
# 3256  https://lda.senate.gov/api/v1/filings/757c4139...
# 3986  https://lda.senate.gov/api/v1/filings/f2cb79d8...
# 3882  https://lda.senate.gov/api/v1/filings/1264d8e9...
# 3958  https://lda.senate.gov/api/v1/filings/de25992d...
# 4153  https://lda.senate.gov/api/v1/filings/c59e19b3...
#
#                                filing_uuid filing_type filing_type_display  \
# 204   3199e1d1-4f27-441e-845f-cda2a7f46dbc          RR        Registration
# 3880  202792f1-1b03-4653-9569-e18c087afca0          RR        Registration
# 2653  52508a4d-7dc0-4698-bc1c-a20a179562b2          RR        Registration
# 3566  0e461030-6f88-4167-96eb-de5ce5b9e6ed          RR        Registration
# 2372  650b9e5a-b4d0-4def-8dae-fcf63eb78a26          RR        Registration
# ...                                    ...         ...                 ...
# 3256  757c4139-ec01-42f2-89d1-17bc7772bfaf          RR        Registration
# 3986  f2cb79d8-6df4-4327-b9d8-003e88c3a342          RR        Registration
# 3882  1264d8e9-c889-4a3b-af09-d7a6d6405d0a          RR        Registration
# 3958  de25992d-b8fa-458e-9ef4-dafe39d50015          RR        Registration
# 4153  c59e19b3-8b36-4c87-9a90-175288ee081f          RR        Registration
#
#       filing_year   filing_period          filing_period_display  \
# 204          2023   first_quarter   1st Quarter (Jan 1 - Mar 31)
# 3880         2023  fourth_quarter   4th Quarter (Oct 1 - Dec 31)
# 2653         2023   third_quarter  3rd Quarter (July 1 - Sep 30)
# 3566         2023  fourth_quarter   4th Quarter (Oct 1 - Dec 31)
# 2372         2023   third_quarter  3rd Quarter (July 1 - Sep 30)
# ...           ...             ...                            ...
# 3256         2023   third_quarter  3rd Quarter (July 1 - Sep 30)
# 3986         2023   third_quarter  3rd Quarter (July 1 - Sep 30)
# 3882         2023  fourth_quarter   4th Quarter (Oct 1 - Dec 31)
# 3958         2023  fourth_quarter   4th Quarter (Oct 1 - Dec 31)
# 4153         2023  fourth_quarter   4th Quarter (Oct 1 - Dec 31)
#
#                                     filing_document_url  \
# 204   https://lda.senate.gov/filings/public/filing/3...
# 3880  https://lda.senate.gov/filings/public/filing/2...
# 2653  https://lda.senate.gov/filings/public/filing/5...
# 3566  https://lda.senate.gov/filings/public/filing/0...
# 2372  https://lda.senate.gov/filings/public/filing/6...
# ...                                                 ...
# 3256  https://lda.senate.gov/filings/public/filing/7...
# 3986  https://lda.senate.gov/filings/public/filing/f...
# 3882  https://lda.senate.gov/filings/public/filing/1...
# 3958  https://lda.senate.gov/filings/public/filing/d...
# 4153  https://lda.senate.gov/filings/public/filing/c...
#
#      filing_document_content_type  income  ...  registrant_state  \
# 204                     text/html     NaN  ...                DC
# 3880                    text/html     NaN  ...                DC
# 2653                    text/html     NaN  ...                DC
# 3566                    text/html     NaN  ...                DC
# 2372                    text/html     NaN  ...                DC
# ...                           ...     ...  ...               ...
# 3256                    text/html     NaN  ...                DC
# 3986                    text/html     NaN  ...                CA
# 3882                    text/html     NaN  ...                FL
# 3958                    text/html     NaN  ...                DC
# 4153                    text/html     NaN  ...                DC
#
#       registrant_zip                                         registrant  \
# 204          20006.0  {'id': 682, 'url': 'https://lda.senate.gov/api...
# 3880         20005.0  {'id': 795, 'url': 'https://lda.senate.gov/api...
# 2653         20004.0  {'id': 7257, 'url': 'https://lda.senate.gov/ap...
# 3566         20004.0  {'id': 7257, 'url': 'https://lda.senate.gov/ap...
# 2372         20007.0  {'id': 15042, 'url': 'https://lda.senate.gov/a...
# ...              ...                                                ...
# 3256         20006.0  {'id': 401107944, 'url': 'https://lda.senate.g...
# 3986         94025.0  {'id': 401108060, 'url': 'https://lda.senate.g...
# 3882         33140.0  {'id': 401108086, 'url': 'https://lda.senate.g...
# 3958         20007.0  {'id': 401108110, 'url': 'https://lda.senate.g...
# 4153         20011.0  {'id': 401108161, 'url': 'https://lda.senate.g...
#
#                                                  client  \
# 204   {'id': 54272, 'url': 'https://lda.senate.gov/a...
# 3880  {'id': 58093, 'url': 'https://lda.senate.gov/a...
# 2653  {'id': 56841, 'url': 'https://lda.senate.gov/a...
# 3566  {'id': 57772, 'url': 'https://lda.senate.gov/a...
# 2372  {'id': 56550, 'url': 'https://lda.senate.gov/a...
# ...                                                 ...
# 3256  {'id': 57453, 'url': 'https://lda.senate.gov/a...
# 3986  {'id': 58238, 'url': 'https://lda.senate.gov/a...
# 3882  {'id': 58095, 'url': 'https://lda.senate.gov/a...
# 3958  {'id': 58199, 'url': 'https://lda.senate.gov/a...
# 4153  {'id': 58502, 'url': 'https://lda.senate.gov/a...
#
#                                     lobbying_activities  \
# 204   [{'general_issue_code': 'MAN', 'general_issue_...
# 3880  [{'general_issue_code': 'COM', 'general_issue_...
# 2653  [{'general_issue_code': 'HCR', 'general_issue_...
# 3566  [{'general_issue_code': 'GOV', 'general_issue_...
# 2372  [{'general_issue_code': 'ECN', 'general_issue_...
# ...                                                 ...
# 3256  [{'general_issue_code': 'CSP', 'general_issue_...
# 3986  [{'general_issue_code': 'SMB', 'general_issue_...
# 3882  [{'general_issue_code': 'FAM', 'general_issue_...
# 3958  [{'general_issue_code': 'ENV', 'general_issue_...
# 4153  [{'general_issue_code': 'SMB', 'general_issue_...
#
#       conviction_disclosures  \
# 204                       []
# 3880                      []
# 2653                      []
# 3566                      []
# 2372                      []
# ...                      ...
# 3256                      []
# 3986                      []
# 3882                      []
# 3958                      []
# 4153                      []
#
#                                        foreign_entities  \
# 204                                                  []
# 3880                                                 []
# 2653                                                 []
# 3566  [{'name': 'YUKSEL YILDIRIM', 'contribution': '...
# 2372                                                 []
# ...                                                 ...
# 3256                                                 []
# 3986                                                 []
# 3882                                                 []
# 3958                                                 []
# 4153                                                 []
#
#      affiliated_organizations registrant_id client_id
# 204                        []           682     54272
# 3880                       []           795     58093
# 2653                       []          7257     56841
# 3566                       []          7257     57772
# 2372                       []         15042     56550
# ...                       ...           ...       ...
# 3256                       []     401107944     57453
# 3986                       []     401108060     58238
# 3882                       []     401108086     58095
# 3958                       []     401108110     58199
# 4153                       []     401108161     58502
#
# [196 rows x 32 columns]

# %%
lobbying_2023_RA.sort_values(["registrant_id","client_id"])
# Out:
#                                                    url  \
# 348  https://lda.senate.gov/api/v1/filings/aa865755...
# 485  https://lda.senate.gov/api/v1/filings/9840a454...
# 476  https://lda.senate.gov/api/v1/filings/97b92a95...
# 352  https://lda.senate.gov/api/v1/filings/286588cd...
# 439  https://lda.senate.gov/api/v1/filings/79e28204...
# ..                                                 ...
# 378  https://lda.senate.gov/api/v1/filings/b3517459...
# 490  https://lda.senate.gov/api/v1/filings/4e63bb22...
# 505  https://lda.senate.gov/api/v1/filings/1cd5b424...
# 519  https://lda.senate.gov/api/v1/filings/4282489a...
# 515  https://lda.senate.gov/api/v1/filings/66f1a815...
#
#                               filing_uuid filing_type  \
# 348  aa865755-4d17-4399-ad70-5487c65029f2          RA
# 485  9840a454-645c-40cb-86b0-8949aa1094be          RA
# 476  97b92a95-345d-429b-b2ed-54ea50ea7fc0          RA
# 352  286588cd-7cfd-4a82-a4a0-c5bd9265f868          RA
# 439  79e28204-9f04-4d2a-a8ab-f83cef800b76          RA
# ..                                    ...         ...
# 378  b3517459-911a-4f97-a58f-85e01ce350e3          RA
# 490  4e63bb22-ab56-4322-951d-983bde7d12e9          RA
# 505  1cd5b424-a273-42b8-8f75-904cded3e591          RA
# 519  4282489a-7a96-43a2-98ab-e8b6444b70ae          RA
# 515  66f1a815-ac70-4246-9fd0-c8b66a8059d8          RA
#
#           filing_type_display  filing_year   filing_period  \
# 348  Registration - Amendment         2023   third_quarter
# 485  Registration - Amendment         2023  fourth_quarter
# 476  Registration - Amendment         2023  fourth_quarter
# 352  Registration - Amendment         2023   third_quarter
# 439  Registration - Amendment         2023  fourth_quarter
# ..                        ...          ...             ...
# 378  Registration - Amendment         2023   third_quarter
# 490  Registration - Amendment         2023   third_quarter
# 505  Registration - Amendment         2023  fourth_quarter
# 519  Registration - Amendment         2023  fourth_quarter
# 515  Registration - Amendment         2023  fourth_quarter
#
#              filing_period_display  \
# 348  3rd Quarter (July 1 - Sep 30)
# 485   4th Quarter (Oct 1 - Dec 31)
# 476   4th Quarter (Oct 1 - Dec 31)
# 352  3rd Quarter (July 1 - Sep 30)
# 439   4th Quarter (Oct 1 - Dec 31)
# ..                             ...
# 378  3rd Quarter (July 1 - Sep 30)
# 490  3rd Quarter (July 1 - Sep 30)
# 505   4th Quarter (Oct 1 - Dec 31)
# 519   4th Quarter (Oct 1 - Dec 31)
# 515   4th Quarter (Oct 1 - Dec 31)
#
#                                    filing_document_url  \
# 348  https://lda.senate.gov/filings/public/filing/a...
# 485  https://lda.senate.gov/filings/public/filing/9...
# 476  https://lda.senate.gov/filings/public/filing/9...
# 352  https://lda.senate.gov/filings/public/filing/2...
# 439  https://lda.senate.gov/filings/public/filing/7...
# ..                                                 ...
# 378  https://lda.senate.gov/filings/public/filing/b...
# 490  https://lda.senate.gov/filings/public/filing/4...
# 505  https://lda.senate.gov/filings/public/filing/1...
# 519  https://lda.senate.gov/filings/public/filing/4...
# 515  https://lda.senate.gov/filings/public/filing/6...
#
#     filing_document_content_type  income  ...  registrant_state  \
# 348                    text/html     NaN  ...                DC
# 485                    text/html     NaN  ...                DC
# 476                    text/html     NaN  ...                DC
# 352                    text/html     NaN  ...                DC
# 439                    text/html     NaN  ...                DC
# ..                           ...     ...  ...               ...
# 378                    text/html     NaN  ...                DC
# 490                    text/html     NaN  ...                CA
# 505                    text/html     NaN  ...                FL
# 519                    text/html     NaN  ...                DC
# 515                    text/html     NaN  ...                DC
#
#      registrant_zip                                         registrant  \
# 348           20006  {'id': 682, 'url': 'https://lda.senate.gov/api...
# 485           20006  {'id': 682, 'url': 'https://lda.senate.gov/api...
# 476           20006  {'id': 682, 'url': 'https://lda.senate.gov/api...
# 352           20006  {'id': 682, 'url': 'https://lda.senate.gov/api...
# 439           20006  {'id': 682, 'url': 'https://lda.senate.gov/api...
# ..              ...                                                ...
# 378           20006  {'id': 401107944, 'url': 'https://lda.senate.g...
# 490           94025  {'id': 401108060, 'url': 'https://lda.senate.g...
# 505           33140  {'id': 401108086, 'url': 'https://lda.senate.g...
# 519           20007  {'id': 401108110, 'url': 'https://lda.senate.g...
# 515           20011  {'id': 401108161, 'url': 'https://lda.senate.g...
#
#                                                 client  \
# 348  {'id': 51841, 'url': 'https://lda.senate.gov/a...
# 485  {'id': 53690, 'url': 'https://lda.senate.gov/a...
# 476  {'id': 54272, 'url': 'https://lda.senate.gov/a...
# 352  {'id': 100528, 'url': 'https://lda.senate.gov/...
# 439  {'id': 101263, 'url': 'https://lda.senate.gov/...
# ..                                                 ...
# 378  {'id': 57453, 'url': 'https://lda.senate.gov/a...
# 490  {'id': 58238, 'url': 'https://lda.senate.gov/a...
# 505  {'id': 58095, 'url': 'https://lda.senate.gov/a...
# 519  {'id': 58199, 'url': 'https://lda.senate.gov/a...
# 515  {'id': 58502, 'url': 'https://lda.senate.gov/a...
#
#                                    lobbying_activities  \
# 348  [{'general_issue_code': 'MAN', 'general_issue_...
# 485  [{'general_issue_code': 'IMM', 'general_issue_...
# 476  [{'general_issue_code': 'CSP', 'general_issue_...
# 352  [{'general_issue_code': 'TAX', 'general_issue_...
# 439  [{'general_issue_code': 'HCR', 'general_issue_...
# ..                                                 ...
# 378  [{'general_issue_code': 'CSP', 'general_issue_...
# 490  [{'general_issue_code': 'SCI', 'general_issue_...
# 505  [{'general_issue_code': 'FIN', 'general_issue_...
# 519  [{'general_issue_code': 'ENV', 'general_issue_...
# 515  [{'general_issue_code': 'DEF', 'general_issue_...
#
#      conviction_disclosures foreign_entities affiliated_organizations  \
# 348                      []               []                       []
# 485                      []               []                       []
# 476                      []               []                       []
# 352                      []               []                       []
# 439                      []               []                       []
# ..                      ...              ...                      ...
# 378                      []               []                       []
# 490                      []               []                       []
# 505                      []               []                       []
# 519                      []               []                       []
# 515                      []               []                       []
#
#     registrant_id client_id
# 348           682     51841
# 485           682     53690
# 476           682     54272
# 352           682    100528
# 439           682    101263
# ..            ...       ...
# 378     401107944     57453
# 490     401108060     58238
# 505     401108086     58095
# 519     401108110     58199
# 515     401108161     58502
#
# [528 rows x 32 columns]

# %% [markdown]
# ### Dropping unnecessary columns

# %% [markdown]
# ### Dealing with dictionaries in the DataFrames

# %% [markdown]
# Some of these columns have dictionaries as entries, namely "registrant" (i.e. lobbyist), "client" (i.e. entity lobbying), "lobbying_activities" (the codes for the issues at hand). Let's just look at these for our filing in question.

# %%
print(lobbying_2023_RR.iloc[57]["registrant"])
print()
print(lobbying_2023_RR.iloc[57]["client"])
print()
print(lobbying_2023_RR.iloc[57]["lobbying_activities"])
# Out:
# {'id': 323318, 'url': 'https://lda.senate.gov/api/v1/registrants/323318/', 'house_registrant_id': 39886, 'name': 'BRODY GROUP L.L.C. PUBLIC AFFAIRS', 'description': 'Public Affairs', 'address_1': '3299 K street NW Suite 401', 'address_2': None, 'address_3': None, 'address_4': None, 'city': 'Washington', 'state': 'DC', 'state_display': 'District of Columbia', 'zip': '20007', 'country': 'US', 'country_display': 'United States of America', 'ppb_country': 'US', 'ppb_country_display': 'United States of America', 'contact_name': 'MR. MIKE BRODY', 'contact_telephone': '+1 202-640-9135', 'dt_updated': '2024-01-26T20:13:12.964123-05:00'}
#
# {'id': 53935, 'url': 'https://lda.senate.gov/api/v1/clients/53935/', 'client_id': 53935, 'name': 'BC ENGINEERED PRODUCTS INC.', 'general_description': 'manufacturing and defense industrial base supplier.', 'client_government_entity': None, 'client_self_select': False, 'state': 'NJ', 'state_display': 'New Jersey', 'country': 'US', 'country_display': 'United States of America', 'ppb_state': 'NJ', 'ppb_state_display': 'New Jersey', 'ppb_country': 'US', 'ppb_country_display': 'United States of America', 'effective_date': '2023-01-13'}
#
# [{'general_issue_code': 'DEF', 'general_issue_code_display': 'Defense', 'description': 'Fiscal Year 2024 Defense Authorization and Appropriation bills, related to Defense Logisitics Agency part cost reduction.', 'foreign_entity_issues': None, 'lobbyists': [{'lobbyist': {'id': 47053, 'prefix': 'mr', 'prefix_display': 'MR.', 'first_name': 'MICHAEL', 'nickname': None, 'middle_name': 'ANDREW', 'last_name': 'BRODY', 'suffix': None, 'suffix_display': None}, 'covered_position': None, 'new': True}], 'government_entities': []}, {'general_issue_code': 'BUD', 'general_issue_code_display': 'Budget/Appropriations', 'description': 'Fiscal Year 2024 Defense Authorization and Appropriation bills, related to Defense Logisitics Agency part cost reduction.', 'foreign_entity_issues': None, 'lobbyists': [{'lobbyist': {'id': 47053, 'prefix': 'mr', 'prefix_display': 'MR.', 'first_name': 'MICHAEL', 'nickname': None, 'middle_name': 'ANDREW', 'last_name': 'BRODY', 'suffix': None, 'suffix_display': None}, 'covered_position': None, 'new': True}], 'government_entities': []}]

# %% [markdown]
# For "registrant" and "client", these entries are actually not dictionaries - rather they are the literal strings representing a dictionary. For "lobbying_activities" we have a string representing a list of dictionaries.

# %%
print("Registrant:", ast.literal_eval(lobbying_2023_RR.iloc[57]["registrant"])["name"])
print()
print("Client:", ast.literal_eval(lobbying_2023_RR.iloc[57]["client"])["name"])
print()
l=len(ast.literal_eval(lobbying_2023_RR.iloc[57]["lobbying_activities"])) #this is the length of the list of dictionaries
for i in range(l):
    print(ast.literal_eval(lobbying_2023_RR.iloc[57]["lobbying_activities"])[i]["general_issue_code"],ast.literal_eval(lobbying_2023_RR.iloc[57]["lobbying_activities"])[i]["description"])
# Out:
# Registrant: BRODY GROUP L.L.C. PUBLIC AFFAIRS
#
# Client: BC ENGINEERED PRODUCTS INC.
#
# DEF Fiscal Year 2024 Defense Authorization and Appropriation bills, related to Defense Logisitics Agency part cost reduction.
# BUD Fiscal Year 2024 Defense Authorization and Appropriation bills, related to Defense Logisitics Agency part cost reduction.

# %%
df.loc[df.!=0][""]
# Out:
# 0       RR
# 1       RR
# 2       RR
# 3       RR
# 4       RR
#         ..
# 4208    RR
# 4209    RR
# 4210    RR
# 4211    RR
# 4212    RR
# Name: filing_type, Length: 4213, dtype: object

# %%
# df=lobbying_2023_RA.drop(["url","filing_uuid","filing_type_display","filing_period_display","filing_document_url","filing_document_content_type","dt_posted",'registrant_country',
#        'registrant_ppb_country', 'registrant_address_1',
#        'registrant_address_2', 'registrant_different_address',
#        'registrant_city', 'registrant_state', 'registrant_zip'], axis=1)

# %%
df["registrant"][0]
# Out:
# "{'id': 28721, 'url': 'https://lda.senate.gov/api/v1/registrants/28721/', 'house_registrant_id': 32570, 'name': 'NATIONAL TRUST FOR HISTORIC PRESERVATION', 'description': 'non-profit for historic preservation', 'address_1': '600 14th Street, N.W.', 'address_2': 'Suite 500', 'address_3': None, 'address_4': None, 'city': 'WASHINGTON', 'state': 'DC', 'state_display': 'District of Columbia', 'zip': '20005', 'country': 'US', 'country_display': 'United States of America', 'ppb_country': 'US', 'ppb_country_display': 'United States of America', 'contact_name': 'MR. CARL R. WOLF', 'contact_telephone': '+1 202-588-6254', 'dt_updated': '2024-01-02T10:35:51.502816-05:00'}"

# %% [markdown]
# This is a string, so we convert to a dictionary using the ast package.

# %%
ast.literal_eval(df["registrant"][0])["name"]
# Out:
# 'NATIONAL TRUST FOR HISTORIC PRESERVATION'

# %%
S=set(RA_uuids).intersection(set(RR_uuids))
S
# Out:
# set()

# %%
lobbying_2023_RR_amended=pd.DataFrame()
for uuid in RA_uuids:
    lobbying_2023_RR_amended=pd.concat([lobbying_2023_RR_amended,lobbying_2023_RR.loc[lobbying_2023_RR.filing_uuid==uuid]], ignore_index=True)

# %%
lobbying_2023_RR_amended
# Out:
# Empty DataFrame
# Columns: [url, filing_uuid, filing_type, filing_type_display, filing_year, filing_period, filing_period_display, filing_document_url, filing_document_content_type, income, expenses, expenses_method, expenses_method_display, posted_by_name, dt_posted, termination_date, registrant_country, registrant_ppb_country, registrant_address_1, registrant_address_2, registrant_different_address, registrant_city, registrant_state, registrant_zip, registrant, client, lobbying_activities, conviction_disclosures, foreign_entities, affiliated_organizations]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# ## Dropping the unimportant columns

# %% [markdown]
# ## Lobbying issue codes
